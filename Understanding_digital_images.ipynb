# %% [markdown]
# Digital images are representations of visual data that are stored as binary code in a computer. They can be created through digital cameras, scanners, or software programs, and are composed of pixels, which are tiny squares of color that combine to form the image.

# %%
from skimage import io
import numpy as np
from matplotlib import pyplot as plt

# %%
image = io.imread("./data/beach.jpg")
image
# Out:
# array([[[ 0,  4, 15],
#         [ 0,  4, 15],
#         [ 0,  4, 15],
#         ...,
#         [ 1,  5, 14],
#         [ 1,  5, 14],
#         [ 1,  5, 14]],
#
#        [[ 0,  4, 15],
#         [ 0,  4, 15],
#         [ 0,  4, 15],
#         ...,
#         [ 1,  5, 14],
#         [ 1,  5, 14],
#         [ 1,  5, 14]],
#
#        [[ 1,  5, 16],
#         [ 1,  5, 16],
#         [ 1,  5, 16],
#         ...,
#         [ 1,  5, 14],
#         [ 1,  5, 14],
#         [ 1,  5, 14]],
#
#        ...,
#
#        [[ 0, 25, 32],
#         [ 0, 25, 32],
#         [ 2, 25, 33],
#         ...,
#         [ 0,  0,  5],
#         [ 0,  0,  5],
#         [ 3,  4,  9]],
#
#        [[ 0, 26, 29],
#         [ 0, 25, 29],
#         [ 0, 23, 28],
#         ...,
#         [ 7,  6, 12],
#         [ 6,  5, 11],
#         [ 0,  0,  5]],
#
#        [[ 0, 25, 27],
#         [ 0, 23, 26],
#         [ 0, 20, 24],
#         ...,
#         [ 3,  2,  8],
#         [ 0,  0,  5],
#         [ 6,  5, 11]]], dtype=uint8)

# %%
image.min(), image.max()
# Out:
# (0, 255)

# %%
random_image = np.random.random([500,500])
print(random_image.min(), random_image.max())
plt.imshow(random_image)
# Out:
# 9.278426596148748e-06 0.9999961802884488

# %%
dark_image = image*0.5
print(dark_image)
# Out:
# [[[ 0.   2.   7.5]
#   [ 0.   2.   7.5]
#   [ 0.   2.   7.5]
#   ...
#   [ 0.5  2.5  7. ]
#   [ 0.5  2.5  7. ]
#   [ 0.5  2.5  7. ]]
#
#  [[ 0.   2.   7.5]
#   [ 0.   2.   7.5]
#   [ 0.   2.   7.5]
#   ...
#   [ 0.5  2.5  7. ]
#   [ 0.5  2.5  7. ]
#   [ 0.5  2.5  7. ]]
#
#  [[ 0.5  2.5  8. ]
#   [ 0.5  2.5  8. ]
#   [ 0.5  2.5  8. ]
#   ...
#   [ 0.5  2.5  7. ]
#   [ 0.5  2.5  7. ]
#   [ 0.5  2.5  7. ]]
#
#  ...
#
#  [[ 0.  12.5 16. ]
#   [ 0.  12.5 16. ]
#   [ 1.  12.5 16.5]
#   ...
#   [ 0.   0.   2.5]
#   [ 0.   0.   2.5]
#   [ 1.5  2.   4.5]]
#
#  [[ 0.  13.  14.5]
#   [ 0.  12.5 14.5]
#   [ 0.  11.5 14. ]
#   ...
#   [ 3.5  3.   6. ]
#   [ 3.   2.5  5.5]
#   [ 0.   0.   2.5]]
#
#  [[ 0.  12.5 13.5]
#   [ 0.  11.5 13. ]
#   [ 0.  10.  12. ]
#   ...
#   [ 1.5  1.   4. ]
#   [ 0.   0.   2.5]
#   [ 3.   2.5  5.5]]]

# %%
print(dark_image.min(), dark_image.max())
# Out:
# 0.0 127.5

# %% [markdown]
# dtypes...
#
# uint8 = 0 to 255
#
# uint16 = 0 to 65535
#
# uint 32 = 0 to ((2**32) - 1) 27 float = -1 to 1 or 0 to 1
#
# int8=-128 to 127
#
# int16 = -32768 to 32767
#
# int32 = -2^31 to 2^^31 - 1
#
# Functions that convert images to desired dtype and properly rescale their values
#
# img_as_float Convert to 64-bit floating point.
#
# img_as_ubyte - Convert to 8-bit uint.
#
# img_as_uint - Convert to 16-bit uint.
#
# img_as_int Convert to 16-bit int.

# %%
dark_image = image
